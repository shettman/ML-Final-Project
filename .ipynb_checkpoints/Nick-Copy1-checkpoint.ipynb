# %%
# Declare Dependencies
import pandas as pd
import numpy as np
import datetime
from datetime import date
# import holidays
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_df = pd.read_csv('DesertInn.csv')
csv_df_edited = csv_df
csv_df_edited.head(10)
# Out:
#    Reservation_No DateMade_Short Arrive_Date_Short  Nights  TotalRate  \
# 0               1     28/06/2016        21/07/2016       3     258.02
# 1              13     28/06/2016        14/07/2016       3     223.50
# 2              15     28/06/2016        14/07/2016       1     420.00
# 3              16     28/06/2016        16/07/2016       1      66.80
# 4              17     28/06/2016        17/07/2016       4     540.00
# 5              18     28/06/2016        21/07/2016       3     258.00
# 6              19     28/06/2016        21/07/2016       3     283.82
# 7              20     28/06/2016        22/07/2016       2     206.00
# 8            1340     17/10/2016        30/10/2016       2     158.00
# 9              24     28/06/2016        25/07/2016       2     247.00
#
#          Room Type    Room        City State Zip Code            Rate_Type
# 0          Double      210    Bellevue    WA    98004  Best Available Rate
# 1          Double      108      Aurora    IL    60506  Best Available Rate
# 2          Double      208         NaN   NaN      NaN  Best Available Rate
# 3             King     107    Bellevue    WA    98004  Best Available Rate
# 4  Rubideaux Condo  Rub #4     Seattle    WA    98117  Best Available Rate
# 5          Double      106    Bellevue    WA    98004  Best Available Rate
# 6     Premier King     105    Bellevue    WA    98004  Best Available Rate
# 7             King     203  Snellville    FL    30039  Best Available Rate
# 8  Sweetheart King     102  Palm Coast    FL    32137  Best Available Rate
# 9          Double      106     Reddick    MA    32686  Best Available Rate

# %%
csv_df_edited.dtypes
# Out:
# Reservation_No         int64
# DateMade_Short        object
# Arrive_Date_Short     object
# Nights                 int64
# TotalRate            float64
# Room Type             object
# Room                  object
# City                  object
# State                 object
# Zip Code              object
# Rate_Type             object
# dtype: object

# %%
csv_df_edited[['booking_day','booking_month','booking_year']] = csv_df_edited['DateMade_Short'].str.split('/', expand=True).astype(int)
csv_df_edited[['reservation_day','reservation_month','reservation_year']] = csv_df_edited['Arrive_Date_Short'].str.split('/', expand=True).astype(int)
print (csv_df_edited.dtypes)
csv_df_edited.head()
csv_df_edited.count()
# Out:
# Reservation_No         int64
# DateMade_Short        object
# Arrive_Date_Short     object
# Nights                 int64
# TotalRate            float64
# Room Type             object
# Room                  object
# City                  object
# State                 object
# Zip Code              object
# Rate_Type             object
# booking_day            int64
# booking_month          int64
# booking_year           int64
# reservation_day        int64
# reservation_month      int64
# reservation_year       int64
# dtype: object
# Reservation_No       7880
# DateMade_Short       7880
# Arrive_Date_Short    7880
# Nights               7880
# TotalRate            7880
# Room Type            7880
# Room                 7880
# City                 3443
# State                1109
# Zip Code             3121
# Rate_Type            7880
# booking_day          7880
# booking_month        7880
# booking_year         7880
# reservation_day      7880
# reservation_month    7880
# reservation_year     7880
# dtype: int64

# %%
print (csv_df_edited.booking_day.unique())
print (csv_df_edited.reservation_day.unique())
print (csv_df_edited.booking_year.unique())
print (csv_df_edited.reservation_year.unique())
print (csv_df_edited.booking_month.unique())
print (csv_df_edited.reservation_month.unique())
# Out:
# [28 17  6 25 19 29 30  1  2 18  7  3 31  5  4  9 10 13 11 12 24 14 15 16
#  20 27 21 22 23 26  8]
# [21 14 16 17 22 30 25 26  3 31  1 19 18  4  6 15 12 13  8 23 24 28 20  7
#  29  2 10 11 27  9  5]
# [2016 2018 2017 2019]
# [2016 2018 2017 2019]
# [ 6 10  2  7 11  4  1  9  8  3  5 12]
# [ 7 10  3  8 11  9  5  4  2  1 12  6]

# %%
csv_df_edited['booking_date']= pd.to_datetime(csv_df_edited.booking_year*10000+csv_df_edited.booking_month*100+csv_df_edited.booking_day,format='%Y%m%d')
csv_df_edited['reservation_date']= pd.to_datetime(csv_df_edited.reservation_year*10000+csv_df_edited.reservation_month*100+csv_df_edited.reservation_day,format='%Y%m%d')
print(csv_df_edited.dtypes)
csv_df_edited.head()
# Out:
# Reservation_No                int64
# DateMade_Short               object
# Arrive_Date_Short            object
# Nights                        int64
# TotalRate                   float64
# Room Type                    object
# Room                         object
# City                         object
# State                        object
# Zip Code                     object
# Rate_Type                    object
# booking_day                   int64
# booking_month                 int64
# booking_year                  int64
# reservation_day               int64
# reservation_month             int64
# reservation_year              int64
# booking_date         datetime64[ns]
# reservation_date     datetime64[ns]
# dtype: object
#    Reservation_No DateMade_Short Arrive_Date_Short  Nights  TotalRate  \
# 0               1     28/06/2016        21/07/2016       3     258.02
# 1              13     28/06/2016        14/07/2016       3     223.50
# 2              15     28/06/2016        14/07/2016       1     420.00
# 3              16     28/06/2016        16/07/2016       1      66.80
# 4              17     28/06/2016        17/07/2016       4     540.00
#
#          Room Type    Room      City State Zip Code            Rate_Type  \
# 0          Double      210  Bellevue    WA    98004  Best Available Rate
# 1          Double      108    Aurora    IL    60506  Best Available Rate
# 2          Double      208       NaN   NaN      NaN  Best Available Rate
# 3             King     107  Bellevue    WA    98004  Best Available Rate
# 4  Rubideaux Condo  Rub #4   Seattle    WA    98117  Best Available Rate
#
#    booking_day  booking_month  booking_year  reservation_day  \
# 0           28              6          2016               21
# 1           28              6          2016               14
# 2           28              6          2016               14
# 3           28              6          2016               16
# 4           28              6          2016               17
#
#    reservation_month  reservation_year booking_date reservation_date
# 0                  7              2016   2016-06-28       2016-07-21
# 1                  7              2016   2016-06-28       2016-07-14
# 2                  7              2016   2016-06-28       2016-07-14
# 3                  7              2016   2016-06-28       2016-07-16
# 4                  7              2016   2016-06-28       2016-07-17

# %%
csv_df_edited.drop(['DateMade_Short', 'Arrive_Date_Short', 'booking_year','booking_day', 'booking_month','reservation_year','reservation_month','reservation_day'], axis=1, inplace=True)
csv_df_edited.head()
# Out:
#    Reservation_No  Nights  TotalRate        Room Type    Room      City State  \
# 0               1       3     258.02          Double      210  Bellevue    WA
# 1              13       3     223.50          Double      108    Aurora    IL
# 2              15       1     420.00          Double      208       NaN   NaN
# 3              16       1      66.80             King     107  Bellevue    WA
# 4              17       4     540.00  Rubideaux Condo  Rub #4   Seattle    WA
#
#   Zip Code            Rate_Type booking_date reservation_date
# 0    98004  Best Available Rate   2016-06-28       2016-07-21
# 1    60506  Best Available Rate   2016-06-28       2016-07-14
# 2      NaN  Best Available Rate   2016-06-28       2016-07-14
# 3    98004  Best Available Rate   2016-06-28       2016-07-16
# 4    98117  Best Available Rate   2016-06-28       2016-07-17

# %%
#create output dataframe
results = []

for index, row in csv_df_edited.iterrows():
    for x in range(row['Nights']):
        reservation_no = row['Reservation_No']
        room_no = row['Room']
        total_nights = row['Nights']
        total_rate = row['TotalRate']
        avg_daily_rate  = total_rate/total_nights
        room_type = row['Room Type']
        rate_type = row['Rate_Type']
        booking_date = row['booking_date']
        reservation_date = row['reservation_date']+datetime.timedelta(days=x)
        reservation_weekday = reservation_date.strftime("%A")
        reservation_date_short = reservation_date.strftime("%d, %B")
        tester = {'reservation_no':reservation_no, 'room_no': room_no, 'total_nights': total_nights,'total_rate': total_rate, 'avg_daily_rate': avg_daily_rate, 'room_type': room_type, 'rate_type':rate_type, 'booking_date':booking_date, 'reservation_date':reservation_date, 'reservation_weekday':reservation_weekday,'reservation_date_short':reservation_date_short}
        results.append(tester)
        
results_df = pd.DataFrame(results)
results_df.head()
# Out:
#    avg_daily_rate booking_date            rate_type reservation_date  \
# 0       86.006667   2016-06-28  Best Available Rate       2016-07-21
# 1       86.006667   2016-06-28  Best Available Rate       2016-07-22
# 2       86.006667   2016-06-28  Best Available Rate       2016-07-23
# 3       74.500000   2016-06-28  Best Available Rate       2016-07-14
# 4       74.500000   2016-06-28  Best Available Rate       2016-07-15
#
#   reservation_date_short  reservation_no reservation_weekday room_no  \
# 0               21, July               1            Thursday     210
# 1               22, July               1              Friday     210
# 2               23, July               1            Saturday     210
# 3               14, July              13            Thursday     108
# 4               15, July              13              Friday     108
#
#   room_type  total_nights  total_rate
# 0   Double              3      258.02
# 1   Double              3      258.02
# 2   Double              3      258.02
# 3   Double              3      223.50
# 4   Double              3      223.50

# %%
results_df['Room Count'] = 1
results_df.head()
# Out:
#    avg_daily_rate booking_date            rate_type reservation_date  \
# 0       86.006667   2016-06-28  Best Available Rate       2016-07-21
# 1       86.006667   2016-06-28  Best Available Rate       2016-07-22
# 2       86.006667   2016-06-28  Best Available Rate       2016-07-23
# 3       74.500000   2016-06-28  Best Available Rate       2016-07-14
# 4       74.500000   2016-06-28  Best Available Rate       2016-07-15
#
#   reservation_date_short  reservation_no reservation_weekday room_no  \
# 0               21, July               1            Thursday     210
# 1               22, July               1              Friday     210
# 2               23, July               1            Saturday     210
# 3               14, July              13            Thursday     108
# 4               15, July              13              Friday     108
#
#   room_type  total_nights  total_rate  Room Count
# 0   Double              3      258.02           1
# 1   Double              3      258.02           1
# 2   Double              3      258.02           1
# 3   Double              3      223.50           1
# 4   Double              3      223.50           1

# %%
# results_df["Month"] = results_df["reservation_date"].map(lambda x: 100*x.year + x.month)
results_df['Month'] = pd.DatetimeIndex(results_df['reservation_date']).month
results_df['Week'] = pd.DatetimeIndex(results_df['reservation_date']).week
results_df['Quarter'] = pd.DatetimeIndex(results_df['reservation_date']).quarter
results_df['Season']=''

results_df.loc[results_df.Month == 12, ['Season']] = 'Winter'
results_df.loc[results_df.Month == 1, ['Season']] = 'Winter'
results_df.loc[results_df.Month == 2, ['Season']] = 'Winter'

results_df.loc[results_df.Month == 3, ['Season']] = 'Spring'
results_df.loc[results_df.Month == 4, ['Season']] = 'Spring'
results_df.loc[results_df.Month == 5, ['Season']] = 'Spring'

results_df.loc[results_df.Month == 6, ['Season']] = 'Summer'
results_df.loc[results_df.Month == 7, ['Season']] = 'Summer'
results_df.loc[results_df.Month == 8, ['Season']] = 'Summer'

results_df.loc[results_df.Month == 9, ['Season']] = 'Fall'
results_df.loc[results_df.Month == 10, ['Season']] = 'Fall'
results_df.loc[results_df.Month == 11, ['Season']] = 'Fall'

results_df.head()
# Out:
#    avg_daily_rate booking_date            rate_type reservation_date  \
# 0       86.006667   2016-06-28  Best Available Rate       2016-07-21
# 1       86.006667   2016-06-28  Best Available Rate       2016-07-22
# 2       86.006667   2016-06-28  Best Available Rate       2016-07-23
# 3       74.500000   2016-06-28  Best Available Rate       2016-07-14
# 4       74.500000   2016-06-28  Best Available Rate       2016-07-15
#
#   reservation_date_short  reservation_no reservation_weekday room_no  \
# 0               21, July               1            Thursday     210
# 1               22, July               1              Friday     210
# 2               23, July               1            Saturday     210
# 3               14, July              13            Thursday     108
# 4               15, July              13              Friday     108
#
#   room_type  total_nights  total_rate  Room Count  Month  Week  Quarter  \
# 0   Double              3      258.02           1      7    29        3
# 1   Double              3      258.02           1      7    29        3
# 2   Double              3      258.02           1      7    29        3
# 3   Double              3      223.50           1      7    28        3
# 4   Double              3      223.50           1      7    28        3
#
#    Season
# 0  Summer
# 1  Summer
# 2  Summer
# 3  Summer
# 4  Summer

# %%
groupByDate_df = results_df.groupby('reservation_date').agg({'Room Count':'sum', 'reservation_weekday':'first', 'avg_daily_rate':'mean','Month':'mean','Week':'mean', 'Quarter':'mean', 'Season':'first', 'avg_daily_rate': 'mean'})
groupByDate_df.head()
# Out:
#                   Room Count reservation_weekday  avg_daily_rate  Month  Week  \
# reservation_date
# 2016-07-01                 1              Friday       57.142857      7    26
# 2016-07-02                 1            Saturday       57.142857      7    26
# 2016-07-03                 1              Sunday       57.142857      7    26
# 2016-07-04                 1              Monday       57.142857      7    27
# 2016-07-05                 1             Tuesday       57.142857      7    27
#
#                   Quarter  Season
# reservation_date
# 2016-07-01              3  Summer
# 2016-07-02              3  Summer
# 2016-07-03              3  Summer
# 2016-07-04              3  Summer
# 2016-07-05              3  Summer

# %%
groupByDateFinal_df = pd.get_dummies(groupByDate_df, columns=['reservation_weekday', 'Month', 'Week', 'Quarter','Season'])
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Monday']*50
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Tuesday']*50
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Wednesday']*50
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Thursday']*50
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Friday']*50
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Saturday']*50
# groupByDateFinal_df['Month_1']=groupByDateFinal_df['reservation_weekday_Sunday']*50

groupByDateFinal_df.head()
# Out:
#                   Room Count  avg_daily_rate  reservation_weekday_Friday  \
# reservation_date
# 2016-07-01                 1       57.142857                           1
# 2016-07-02                 1       57.142857                           0
# 2016-07-03                 1       57.142857                           0
# 2016-07-04                 1       57.142857                           0
# 2016-07-05                 1       57.142857                           0
#
#                   reservation_weekday_Monday  reservation_weekday_Saturday  \
# reservation_date
# 2016-07-01                                 0                             0
# 2016-07-02                                 0                             1
# 2016-07-03                                 0                             0
# 2016-07-04                                 1                             0
# 2016-07-05                                 0                             0
#
#                   reservation_weekday_Sunday  reservation_weekday_Thursday  \
# reservation_date
# 2016-07-01                                 0                             0
# 2016-07-02                                 0                             0
# 2016-07-03                                 1                             0
# 2016-07-04                                 0                             0
# 2016-07-05                                 0                             0
#
#                   reservation_weekday_Tuesday  reservation_weekday_Wednesday  \
# reservation_date
# 2016-07-01                                  0                              0
# 2016-07-02                                  0                              0
# 2016-07-03                                  0                              0
# 2016-07-04                                  0                              0
# 2016-07-05                                  1                              0
#
#                   Month_1  ...  Week_51  Week_52  Quarter_1  Quarter_2  \
# reservation_date           ...
# 2016-07-01              0  ...        0        0          0          0
# 2016-07-02              0  ...        0        0          0          0
# 2016-07-03              0  ...        0        0          0          0
# 2016-07-04              0  ...        0        0          0          0
# 2016-07-05              0  ...        0        0          0          0
#
#                   Quarter_3  Quarter_4  Season_Fall  Season_Spring  \
# reservation_date
# 2016-07-01                1          0            0              0
# 2016-07-02                1          0            0              0
# 2016-07-03                1          0            0              0
# 2016-07-04                1          0            0              0
# 2016-07-05                1          0            0              0
#
#                   Season_Summer  Season_Winter
# reservation_date
# 2016-07-01                    1              0
# 2016-07-02                    1              0
# 2016-07-03                    1              0
# 2016-07-04                    1              0
# 2016-07-05                    1              0
#
# [5 rows x 81 columns]

# %%
# Features: 52 weeks + 12 Mon + 7 Days + 4Q + 4 Seasons +Avgrate = 80

X = groupByDateFinal_df[["reservation_weekday_Monday", "reservation_weekday_Tuesday", "reservation_weekday_Wednesday","reservation_weekday_Thursday", "reservation_weekday_Friday", "reservation_weekday_Saturday","reservation_weekday_Sunday","Month_1","Month_2","Month_3","Month_4", "Month_5","Month_6","Month_7","Month_8","Month_9","Month_10", "Month_11","Month_12",'Week_1','Week_2','Week_3','Week_4','Week_5','Week_6','Week_7','Week_8','Week_9','Week_10','Week_11','Week_12','Week_13','Week_14','Week_15','Week_16','Week_17','Week_18','Week_19','Week_20','Week_21','Week_22','Week_23','Week_24','Week_25','Week_26','Week_27','Week_28','Week_29','Week_30','Week_31','Week_32','Week_33','Week_34','Week_35','Week_36','Week_37','Week_38','Week_39','Week_40','Week_41','Week_42','Week_43','Week_44','Week_45','Week_46','Week_47','Week_48','Week_49','Week_50','Week_51','Week_52','Quarter_1', 'Quarter_2', 'Quarter_3', 'Quarter_4', 'Season_Fall','Season_Spring','Season_Summer','Season_Winter','avg_daily_rate']]
y = groupByDateFinal_df["Room Count"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1223, 80) (1223, 1)

# %%
# Linear model
from sklearn.linear_model import LinearRegression
model_linear = LinearRegression()
model_linear.fit(X, y)
predictions_linear = model_linear.predict(X)

from sklearn.metrics import mean_squared_error, r2_score
mse_linear = mean_squared_error(y, predictions_linear)
r2_linear = r2_score(y, predictions_linear)
print(f"MSE: {mse_linear}, R2: {r2_linear}")
# Out:
# MSE: 12.810800829942092, R2: 0.542891764102724

# %%
# Plot Residuals
plt.scatter(predictions_linear, predictions_linear - y)
plt.hlines(y=0, xmin=predictions_linear.min(), xmax=predictions_linear.max())
plt.show()

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X, y)
predictions_lasso = lasso.predict(X)
mse_lasso = mean_squared_error(y, predictions_lasso)
r2_lasso = lasso.score(X, y)

print(f"MSE: {mse_lasso}, R2: {r2_lasso}")
# Out:
# MSE: 13.328116423002912, R2: 0.5244331820604917

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge
### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X, y)
predictions_ridge = ridge.predict(X)
mse_ridge = mean_squared_error(y, predictions_ridge)
r2_ridge = ridge.score(X, y)
### END SOLUTION
print(f"MSE: {mse_ridge}, R2: {r2_ridge}")
# Out:
# MSE: 12.811044804043117, R2: 0.5428830587475784

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet
### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X, y)
predictions_elastic = elasticnet.predict(X)
mse_elastic = mean_squared_error(y, predictions_elastic)
r2_elastic = elasticnet.score(X, y)
### END SOLUTION
print(f"MSE: {mse_elastic}, R2: {r2_elastic}")
# Out:
# MSE: 13.358519943888147, R2: 0.523348339669965

# %%
# csv_df_2020 = pd.read_csv('2020.csv')
# csv_df_2020[['reservation_month','reservation_day','reservation_year']] = csv_df_2020['date'].str.split('/', expand=True).astype(int)
# csv_df_2020['reservation_date']= pd.to_datetime(csv_df_2020.reservation_year*10000+csv_df_2020.reservation_month*100+csv_df_2020.reservation_day,format='%Y%m%d')

# csv_df_2020.head(20)
